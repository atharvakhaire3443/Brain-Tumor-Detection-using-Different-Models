# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import skimage

from skimage import color, io

# %%
image = io.imread(os.getcwd() + '/Data/Images/Image3.jpg')
io.imshow(image)
plt.show()
plt.close()

# %%
image.shape
# Out:
# (240, 240, 3)

# %%
red, green, blue = np.transpose(np.reshape(image, (-1, 3)))  # separate rgb channels

# %%
np.mean(red)
# Out:
# 43.91387152777778

# %%
np.mean(green)
# Out:
# 43.91387152777778

# %%
np.mean(blue)
# Out:
# 43.91387152777778

# %%
np.amax(red)
# Out:
# 255

# %%
np.amax(green)
# Out:
# 255

# %%
np.amax(blue)
# Out:
# 255
